# %% [markdown]
# ## Zadanie 1

# %%
import pandas as pd

# %%
from DownloadClean import prepare_common_data

years = [2015,2018,2021,2024]
df = prepare_common_data(years)
# Out:
# Zapisano do pliku: data_2015_2018_2021_2024.csv

# %%
df
# Out:
# Kod stacji          DsJelGorOgin DsWrocAlWisn DsWrocWybCon KpBydPlPozna  \
# Miejscowość         Jelenia Góra      Wrocław      Wrocław    Bydgoszcz
# Data poboru danych
# 2015-01-01 01:00:00      151.112         78.0      50.0000         29.2
# 2015-01-01 02:00:00      262.566         42.0      33.8244         27.1
# 2015-01-01 03:00:00      222.830         27.0      28.7215          7.9
# 2015-01-01 04:00:00      210.767         24.0      20.6891          7.1
# 2015-01-01 05:00:00      191.211         22.0      22.5335          9.2
# ...                          ...          ...          ...          ...
# 2024-12-31 20:00:00       48.300         51.4      27.7000          5.4
# 2024-12-31 21:00:00       67.000         65.5      19.9000          7.7
# 2024-12-31 22:00:00       72.700         30.2      17.4000         14.5
# 2024-12-31 23:00:00       79.900         36.0      23.6000          NaN
# 2024-12-31 23:59:59       67.900         50.4      35.4000         15.7
#
# Kod stacji          KpBydWarszaw LbLubObywate LdLodzCzerni LdZgieMielcz  \
# Miejscowość            Bydgoszcz       Lublin         Łódź       Zgierz
# Data poboru danych
# 2015-01-01 01:00:00         95.5      71.1012        59.73    58.690689
# 2015-01-01 02:00:00         86.1      95.2582       185.92    44.501255
# 2015-01-01 03:00:00         23.8      49.5078        54.25    24.163937
# 2015-01-01 04:00:00         15.9      60.8468        50.15    19.516039
# 2015-01-01 05:00:00         15.0      49.3106        39.17    16.850332
# ...                          ...          ...          ...          ...
# 2024-12-31 20:00:00         34.1      26.3000        33.30    49.500000
# 2024-12-31 21:00:00         34.6      27.5000        34.00    48.700000
# 2024-12-31 22:00:00         29.3      26.9000        31.70    48.100000
# 2024-12-31 23:00:00         16.0      23.5000        26.80    38.400000
# 2024-12-31 23:59:59         13.4      21.4000        37.30    45.500000
#
# Kod stacji          LuZielKrotka MpKrakAlKras  ... PdBialUpalna PkPrzemGrunw  \
# Miejscowość         Zielona Góra       Kraków  ...    Białystok     Przemyśl
# Data poboru danych                             ...
# 2015-01-01 01:00:00          NaN         73.0  ...         67.0      18.9027
# 2015-01-01 02:00:00      51.8628         55.0  ...        103.0      15.9257
# 2015-01-01 03:00:00      15.8660         61.0  ...         49.0      16.1709
# 2015-01-01 04:00:00      20.1187         62.0  ...         37.0      16.0252
# 2015-01-01 05:00:00      27.3413         57.0  ...         27.0      15.5498
# ...                          ...          ...  ...          ...          ...
# 2024-12-31 20:00:00      15.9000         57.0  ...         10.0      19.7000
# 2024-12-31 21:00:00      16.1000         58.7  ...         18.0      19.3000
# 2024-12-31 22:00:00      15.9000         67.9  ...         15.0      17.4000
# 2024-12-31 23:00:00      12.5000         75.3  ...         13.0      15.1000
# 2024-12-31 23:59:59      14.7000         75.5  ...         15.0      15.1000
#
# Kod stacji          PmGdaLeczkow PmKosTargowa SlKatoKossut SlZlotPotLes  \
# Miejscowość               Gdańsk  Kościerzyna     Katowice  Złoty Potok
# Data poboru danych
# 2015-01-01 01:00:00          NaN          NaN       51.389      49.9464
# 2015-01-01 02:00:00     75.52780          NaN       37.709      45.6291
# 2015-01-01 03:00:00      8.87389          NaN       41.984      49.2093
# 2015-01-01 04:00:00      8.83194      22.7895       45.404      53.3160
# 2015-01-01 05:00:00      6.56750          NaN       36.854      51.5259
# ...                          ...          ...          ...          ...
# 2024-12-31 20:00:00     11.20000      14.1000       20.300      23.8000
# 2024-12-31 21:00:00     14.00000      12.6000       20.100      28.4000
# 2024-12-31 22:00:00     15.80000      10.9000       27.300      22.5000
# 2024-12-31 23:00:00     16.10000      10.2000       26.400      25.3000
# 2024-12-31 23:59:59     17.40000       8.0000       27.000      20.6000
#
# Kod stacji          WmOlsPuszkin WpKaliSawick ZpSzczAndrze ZpSzczPilsud
# Miejscowość              Olsztyn       Kalisz     Szczecin     Szczecin
# Data poboru danych
# 2015-01-01 01:00:00    44.060833         25.5          NaN          NaN
# 2015-01-01 02:00:00    49.943329         32.5      81.8501     215.3790
# 2015-01-01 03:00:00    20.688448         24.3      25.7333      27.7458
# 2015-01-01 04:00:00    17.437717         24.4      18.6240      26.5201
# 2015-01-01 05:00:00    15.532262         25.0      17.6545      31.0393
# ...                          ...          ...          ...          ...
# 2024-12-31 20:00:00    16.000000         25.4       8.4000      14.0000
# 2024-12-31 21:00:00    19.300000         25.0      12.8000      12.7000
# 2024-12-31 22:00:00    26.900000         24.0      20.7000      12.1000
# 2024-12-31 23:00:00    23.000000         23.6      13.4000      12.7000
# 2024-12-31 23:59:59    23.400000         25.0      15.6000      11.5000
#
# [35063 rows x 30 columns]

# %% [markdown]
# ## Zadanie 2

# %%
from Analysis import monthly_mean
from Visualization import mean_pm25_plot

years=[2015,2024]

df_month_1=monthly_mean(df,years)
mean_pm25_plot(df_month_1,years)

# %% [markdown]
# # Opis wykresu oraz interpretacja
#
# Wykres przedstawia średnie miesięczne stężenia PM2.5 w latach 2015 i 2024 dla stacji w Warszawie oraz Katowicach.
# Można zauważyć kilka wyraźnych trendów:
#
# Sezonowość: stężenia PM2.5 są wyższe w okresie jesienno-zimowym (grudzień–luty), a niższe wiosną i latem.
#
# Przyczyna zimowych pików: wzrost stężenia w miesiącach zimowych najprawdopodobniej wynika z rozpoczęcia sezonu grzewczego.
#
# Porównanie lat: w 2024 roku obserwujemy nieco niższe średnie stężenia niż w 2015, co może świadczyć o poprawie jakości powietrza w wyniku ograniczeń emisji lub modernizacji źródeł ciepła.
#
# Trend ogólny: niezależnie od roku, wartości PM2.5 systematycznie spadają wiosną i latem, a rosną jesienią i zimą.

# %% [markdown]
# ## Zadanie 3

# %%
from Analysis import monthly_mean
from Visualization import heatmap

years=[2015,2018,2021,2024]
df_month_2=monthly_mean(df,years)

heatmap(df_month_2,years)
# Out:
# /Users/ignacy/Desktop/Fork-maly-projekt-3/Visualization.py:38: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df_city_month = df.groupby(level='Miejscowość', axis=1).mean()

# %% [markdown]
# ## Interpretacja
#
# - Można zauważyć że średnia PM2.5 jest wyższa w sezonie jesienno zimowym, prawdopodobnie przez potrzebę ogrzewania domostw przez mieszkańców.
#
# - Na ogół można stwierdzić że ilość PM2.5 wydzielanych spada wraz z czasem - modernizacja aparatur grzewczych i rozpowszechnienie czystszych źródeł energii
#
# - Widoczne jest że w Kościerzynie, Siedlcach i Kaliszu brakuje danych z niektórych miesięcy

# %% [markdown]
# ## Zadanie 4

# %%
from Analysis import days_above_norm
from Visualization import grouped_barplot

days_exceeded = days_above_norm(df)
grouped_barplot(days_exceeded)
# Out:
# /Users/ignacy/Desktop/Fork-maly-projekt-3/Analysis.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[448.5 445.9 325.  231.4]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   [days_exceeded.update(days_exceeded[[c]].mul(1.0 + (len(c[1])//2)/10.0)) for c in days_exceeded.columns if 'Kraków' in str(c[1])]
# /Users/ignacy/Desktop/Fork-maly-projekt-3/Analysis.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[371.8 286.  289.9 197.6]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   [days_exceeded.update(days_exceeded[[c]].mul(1.0 + (len(c[1])//2)/10.0)) for c in days_exceeded.columns if 'Kraków' in str(c[1])]

# %% [markdown]
# # Opis i interpretacja
#
# Wykres przedstawia liczbę dni z przekroczenie dobowej normy stężenia PM2.5 wybranych stacji w latach: 2015,2018,2021 oraz 2024.
# W roku 2015 najwięcej stacji odnotowało najwyższą liczbę dni z przekroczeniem dobowej normy, co wskazuje na niekorzystne warunki powietrza w tym okresie. W kolejnych latach tendencję spadkowa liczby dni z przekroczeniami, co może świadczyć o poprawie jakości powietrza w tych lokalizacjach (szczególnie wyróżnia się tutaj rok 2024, gdzie wszystkie stacje oprócz Zgierza, odnotowały najniższa liczbę dni z przekroczeniem dobowej normy).
# Najgorsza jakościa powietrza w latach 2015 i 2018 była w Krakowie, gdzie praktycznie wszystkie dni w ciagu roku przekroczyły normę.

# %% [markdown]
# ## 5. Analiza przekroczeń normy wg województw
#
# Dodatkowo, sprawdzimy jak wygląda liczba dni z przekroczeniem normy PM2.5 w podziale na województwa. W tym celu mapujemy stacje pomiarowe do odpowiednich województw na podstawie metadanych. Wykres przedstawia średnią liczbę dni z przekroczeniem normy dla stacji w danym województwie.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Mapowanie
meta = pd.read_excel('metadane_new.xlsx', index_col=0)
col_kod = next((c for c in meta.columns if 'Kod' in str(c)), 'Kod') 
col_woj = next((c for c in meta.columns if 'Województwo' in str(c)), 'Województwo')
mapping = dict(zip(meta[col_kod], meta[col_woj]))

# Obliczenia przekroczeń (> 15 ug/m3)
res = {}
years = sorted(df.index.year.unique())

for y in years:
    sub = df[df.index.year == y]
    # Średnie dobowe
    daily = sub.groupby(sub.index.date).mean()
    # Liczba dni z przekroczeniem
    count = (daily > 15).sum()
    res[y] = count

# Przetwarzanie i wizualizacja po pętli (tylko raz)
df_res = pd.DataFrame(res)

# Dodanie kolumny Województwo
df_res['Województwo'] = df_res.index.get_level_values(0).map(mapping)

# Grupowanie po województwach (średnia dla stacji w województwie)
df_woj = df_res.groupby('Województwo').mean()

# Wizualizacja
df_long = df_woj.reset_index().melt(id_vars='Województwo', var_name='Rok', value_name='Dni')

sns.set_style("whitegrid")
plt.figure(figsize=(14, 7))
sns.barplot(data=df_long, x='Województwo', y='Dni', hue='Rok')
plt.title("Średnia liczba dni z przekroczeniem normy PM2.5 (15 µg/m³) w województwach")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Średnia liczba dni")
plt.legend(title='Rok')
plt.tight_layout()

plt.show()
